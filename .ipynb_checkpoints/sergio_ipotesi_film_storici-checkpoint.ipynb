# %%
import pandas as pd
import pymongo
from pymongo import MongoClient
connection = MongoClient()

db = connection.movie_dataset
crew = db.crew

# %% [markdown]
# # Trova i costumisti e quanti sono

# %%
costume_crew = pd.DataFrame(crew.find({"department": "Costume & Make-Up"}))
costume_crew
# Out:
#                             _id                 credit_id         department  \
# 0      5f510ba1a9e826701e40c2cd  52fe4292c3a36847f80291bb  Costume & Make-Up
# 1      5f510ba1a9e826701e40c2d6  564717adc3a3682611002c07  Costume & Make-Up
# 2      5f510ba1a9e826701e40c2dd  564717949251413e7f002a36  Costume & Make-Up
# 3      5f510ba1a9e826701e40c2de  564717f19251413adb002c49  Costume & Make-Up
# 4      5f510ba1a9e826701e40c2df  5647180a9251413adb002c52  Costume & Make-Up
# ...                         ...                       ...                ...
# 30845  5f510cada9e826701e505fae  56ff7440c3a3686e9e0014cd  Costume & Make-Up
# 30846  5f510cada9e826701e505faf  56ff745a925141677d001538  Costume & Make-Up
# 30847  5f510cada9e826701e505fb9  5823404cc3a368330b00cb6e  Costume & Make-Up
# 30848  5f510cada9e826701e505fd1  5894ae1992514142800081fc  Costume & Make-Up
# 30849  5f510cada9e826701e505fd2  5894ae46c3a36840a70083f8  Costume & Make-Up
#
#        person_id  movie_id
# 0         8527.0     949.0
# 1      1535950.0     949.0
# 2      1535949.0     949.0
# 3         8870.0     949.0
# 4        16551.0     949.0
# ...          ...       ...
# 30845  1599742.0  390959.0
# 30846  1599742.0  390959.0
# 30847     5493.0  390959.0
# 30848  1749861.0  439050.0
# 30849  1749862.0  439050.0
#
# [30850 rows x 5 columns]

# %%
costume_crew['person_id'].nunique()
# Out:
# 12434

# %% [markdown]
# # Trova l'ID del genere 'History'

# %%
genres = db.genres
pd.DataFrame(genres.find({"name": "History"}))
# Out:
#    _id     name
# 0   36  History

# %% [markdown]
# # Recupera gli ID dei migliori film di genere storico

# %%
metadata = db.metadata
metadata_dataframe = pd.DataFrame(metadata.find({'genres': 36})).astype({'_id': 'int32'})
metadata_dataframe = metadata_dataframe[metadata_dataframe['vote_count'] >= 10]
metadata_dataframe = metadata_dataframe.sort_values('vote_average', ascending=False)
metadata_dataframe
# Out:
#          _id  adult  belongs_to_collection    budget                genres  \
# 269    31217  False                85473.0         0       [10752, 18, 36]
# 307    34528  False                85473.0         0       [10752, 18, 36]
# 309    34530  False                85473.0         0       [10752, 18, 36]
# 302      803  False                    NaN         0       [36, 99, 10752]
# 1152  215740  False                    NaN         0              [18, 36]
# ...      ...    ...                    ...       ...                   ...
# 462    19495  False                    NaN  25000000       [28, 36, 10752]
# 794     2911  False                    NaN         0   [28, 80, 36, 10752]
# 526    14977  False                    NaN         0  [28, 12, 18, 36, 27]
# 1035  128767  False                    NaN         0              [36, 12]
# 507    34867  False                    NaN         0  [18, 27, 80, 53, 36]
#
#      original_language                               original_title  \
# 269                 ja                          人間の條件　第１部純愛篇／第２部激怒篇
# 307                 ja                          人間の條件　第３部望郷篇／第４部戦雲篇
# 309                 ja                                    人間の條件　完結篇
# 302                 fr                           Nuit et brouillard
# 1152                de  Die andere Heimat - Chronik einer Sehnsucht
# ...                ...                                          ...
# 462                 en                                        Nomad
# 794                 en                                The Last Drop
# 526                 en                                    Red Sands
# 1035                el                    Ο Θεός Αγαπάει το Χαβιάρι
# 507                 en                            The Manson Family
#
#                                                overview popularity  \
# 269   The Human Condition is a Japanese epic film tr...    2.75699
# 307   Kaji, having lost his exemption from military ...    1.91477
# 309   The Japanese forces having been shattered, Kaj...    2.32728
# 302   The documentary film from French director Resn...    11.1447
# 1152  Follow-up to the TV trilogy "Heimat", this tim...   1.824098
# ...                                                 ...        ...
# 462   The Nomad is a historical epic set in 18th-cen...    8.76278
# 794   Different factions in WWII-era Holland race to...    1.63136
# 526   During a mission in the Middle East, a group o...    3.15925
# 1035  The true-life, stranger-than-fiction tale of e...    1.73165
# 507   Jim Van Bebber's "The Manson Family" is an ext...   0.683586
#
#                            poster_path  ... release_date revenue runtime  \
# 269   /5wF521QDBJplvbQq3lxWY3uYupU.jpg  ...   1959-01-15     0.0   208.0
# 307   /svdKfhT9WLfrC8zgOWmZt4mgyK0.jpg  ...   1959-11-20     0.0   181.0
# 309   /svdKfhT9WLfrC8zgOWmZt4mgyK0.jpg  ...   1961-01-28     0.0   191.0
# 302   /2iWYQia8enOai7QEO3TvenleD7r.jpg  ...   1955-01-01     0.0    32.0
# 1152  /jxuhSQ7glNSAn5zYXV0fVNyQlji.jpg  ...   2013-10-03     0.0   225.0
# ...                                ...  ...          ...     ...     ...
# 462   /jSYw5pbtfF22UIEBwuPnsbUawrZ.jpg  ...   2005-07-17     0.0   112.0
# 794   /gPdQSFgllfBJ7b7RMKSlBuZIGZt.jpg  ...   2005-05-23     0.0   103.0
# 526   /85Es9wILCehlEo95PgOkSDqygSM.jpg  ...   2009-02-24     0.0    89.0
# 1035  /9jZhUIiQpsTnCajIWSSbzYlp9TO.jpg  ...   2012-10-11     0.0    99.0
# 507   /6NfEGeiNufCFkaWZbRyrr6UNQv4.jpg  ...   2003-08-18     0.0    95.0
#
#       spoken_languages    status  \
# 269           [ja, zh]  Released
# 307       [ja, zh, ru]  Released
# 309       [ja, zh, ru]  Released
# 302               [fr]  Released
# 1152              [de]  Released
# ...                ...       ...
# 462       [en, kk, ro]  Released
# 794               [en]  Released
# 526           [en, pl]  Released
# 1035      [ru, el, en]  Released
# 507               [en]  Released
#
#                                                 tagline  \
# 269                                  The Immortal Story
# 307             First Sequel of an Anti-War Masterpiece
# 309               Love is the Condition for Being Human
# 302                                                 NaN
# 1152                                                NaN
# ...                                                 ...
# 462                               Courage know no limit
# 794   What better time for a heist than in the fog o...
# 526                                                 NaN
# 1035                                                NaN
# 507   You've seen the story through the eyes of the ...
#
#                                             title  video vote_average  \
# 269        The Human Condition I: No Greater Love  False          8.5
# 307      The Human Condition II: Road to Eternity  False          8.5
# 309   The Human Condition III: A Soldier's Prayer  False          8.4
# 302                                 Night and Fog  False          8.3
# 1152       Home from Home – Chronicle of a Vision  False          8.3
# ...                                           ...    ...          ...
# 462                            Nomad: The Warrior  False          4.3
# 794                                 The Last Drop  False          4.2
# 526                                     Red Sands  False          4.0
# 1035                             God Loves Caviar  False          3.9
# 507                             The Manson Family  False          3.6
#
#       vote_count
# 269         42.0
# 307         31.0
# 309         28.0
# 302         97.0
# 1152        12.0
# ...          ...
# 462         17.0
# 794         12.0
# 526         32.0
# 1035        11.0
# 507         10.0
#
# [823 rows x 22 columns]

# %%
id_list = metadata_dataframe['_id']
id_list
# Out:
# 269      31217
# 307      34528
# 309      34530
# 302        803
# 1152    215740
#          ...
# 462      19495
# 794       2911
# 526      14977
# 1035    128767
# 507      34867
# Name: _id, Length: 823, dtype: int32

# %% [markdown]
# # Trova i costumisti che hanno partecipato a più film storici

# %%
best_costume_crew = costume_crew[costume_crew['movie_id'].isin(id_list)]
costume_count = best_costume_crew.groupby('person_id').count().sort_values('movie_id', ascending=False)
costume_count = costume_count['_id']
costume_count
# Out:
# person_id
# 26175.0      6
# 9247.0       6
# 4061.0       5
# 461.0        4
# 17166.0      4
#             ..
# 1303052.0    1
# 1304201.0    1
# 1304298.0    1
# 1304433.0    1
# 1890086.0    1
# Name: _id, Length: 1234, dtype: int64

# %% [markdown]
# # Grafico con valutazioni dei film (Y) per i 10 più prolifici costumisti (X)

# %%
import matplotlib.pyplot as plt
import numpy as np

for i in range(10):
    person = costume_count.index[i]
    participated_movies = costume_crew[costume_crew['person_id'] == person]
    participated_movies = participated_movies['movie_id']
    resulting_dataframe = metadata_dataframe[metadata_dataframe['_id'].isin(participated_movies.astype('int32'))]
    average_vote = resulting_dataframe['vote_average']
    plt.scatter(np.full(average_vote.shape, i, dtype=int), average_vote)

plt.show()

# %% [markdown]
# # Voti (Y) di tutti i film dei costumisti (X) che hanno partecipato ai 20 migliori e peggiori film

# %%
best_hfilms = metadata_dataframe.head(20)
best_hcostume = costume_crew[costume_crew['movie_id'].isin(best_hfilms['_id'])]
best_hcostume_count = best_hcostume['person_id'].astype('int32')

for i in range(best_hcostume_count.shape[0]):
    person = best_hcostume_count.iloc[i]
    participated_movies = costume_crew[costume_crew['person_id'] == person]
    participated_movies = participated_movies['movie_id']
    resulting_dataframe = metadata_dataframe[metadata_dataframe['_id'].isin(participated_movies.astype('int32'))]
    average_vote = resulting_dataframe['vote_average']
    plt.scatter(np.full(average_vote.shape, i, dtype=int), average_vote)

plt.show()

# %%
worst_hfilms = metadata_dataframe.tail(20)
worst_hcostume = costume_crew[costume_crew['movie_id'].isin(worst_hfilms['_id'])]
worst_hcostume_count = worst_hcostume['person_id'].astype('int32')

for i in range(worst_hcostume_count.shape[0]):
    person = worst_hcostume_count.iloc[i]
    participated_movies = costume_crew[costume_crew['person_id'] == person]
    participated_movies = participated_movies['movie_id']
    resulting_dataframe = metadata_dataframe[metadata_dataframe['_id'].isin(participated_movies.astype('int32'))]
    average_vote = resulting_dataframe['vote_average']
    plt.scatter(np.full(average_vote.shape, i, dtype=int), average_vote)

plt.show()

# %% [markdown]
# # Come prima, ma considerando solo i costumisti che hanno partecipato ad almeno 3 film

# %%
best_hfilms = metadata_dataframe.head(50)
many_films_crew = costume_crew[costume_crew['person_id'].isin(costume_count[costume_count >= 3].index)]
best_hcostume = many_films_crew[many_films_crew['movie_id'].isin(best_hfilms['_id'])]
best_hcostume_count = best_hcostume['person_id'].astype('int32')

for i in range(best_hcostume_count.shape[0]):
    person = best_hcostume_count.iloc[i]
    participated_movies = costume_crew[costume_crew['person_id'] == person]
    participated_movies = participated_movies['movie_id']
    resulting_dataframe = metadata_dataframe[metadata_dataframe['_id'].isin(participated_movies.astype('int32'))]
    average_vote = resulting_dataframe['vote_average']
    plt.scatter(np.full(average_vote.shape, i, dtype=int), average_vote)

plt.show()

# %%
worst_hfilms = metadata_dataframe.tail(55)
worst_hcostume = many_films_crew[many_films_crew['movie_id'].isin(worst_hfilms['_id'])]
worst_hcostume_count = worst_hcostume['person_id'].astype('int32')

for i in range(worst_hcostume_count.shape[0]):
    person = worst_hcostume_count.iloc[i]
    participated_movies = costume_crew[costume_crew['person_id'] == person]
    participated_movies = participated_movies['movie_id']
    resulting_dataframe = metadata_dataframe[metadata_dataframe['_id'].isin(participated_movies.astype('int32'))]
    average_vote = resulting_dataframe['vote_average']
    plt.scatter(np.full(average_vote.shape, i, dtype=int), average_vote)

plt.show()

# %%
connection.close()
